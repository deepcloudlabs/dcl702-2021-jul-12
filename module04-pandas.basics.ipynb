# %%
# Data
# 1. Tabular -> i) RDBMS ii) JSON -> dictionary
# 2. Heterogeneous 
# Pandas -> NumPy

# %%
# Data 
#  i) Time Series (streaming data) -> network (http/websocket/...), kafka/rabbitmq/...
# ii) DataFrame (static data) -> file (json/csv/...), db, ...

# %%
# Pandas
# Time Series

# %%
import pandas as pd
import numpy as np
print("pandas version: ", pd.__version__)
print("numpy version: ", np.__version__)
# Out:
# pandas version:  1.1.5
# numpy version:  1.19.5

# %%
ts1 = pd.Series([8, 24, 16, 4, 42])

# %%
ts1
# Out:
# 0     8
# 1    24
# 2    16
# 3     4
# 4    42
# dtype: int64

# %%
ts1.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
ts1.values
# Out:
# array([ 8, 24, 16,  4, 42])

# %%
type(ts1.values)
# Out:
# numpy.ndarray

# %%
ts1[2]
# Out:
# 16

# %%
ts1[1:3]
# Out:
# 1    24
# 2    16
# dtype: int64

# %%
ts2 = pd.Series([8, 24, 16, 4, 42], index=['a','b','c','d','e'])

# %%
ts2.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
ts2
# Out:
# a     8
# b    24
# c    16
# d     4
# e    42
# dtype: int64

# %%
ts2['b']
# Out:
# 24

# %%
ts2['a':'d']
# Out:
# a     8
# b    24
# c    16
# d     4
# dtype: int64

# %%
ts1[[0,3,2]]
# Out:
# 0     8
# 3     4
# 2    16
# dtype: int64

# %%
ts1[ts1>16] ** 3
# Out:
# 1    13824
# 4    74088
# dtype: int64

# %%
np.sqrt(ts1[ts1>16])
# Out:
# 1    4.898979
# 4    6.480741
# dtype: float64

# %%
names = ['jack', 'kate', 'james']
'jack' in names
# Out:
# True

# %%
'ben' in names
# Out:
# False

# %%
'b' in ts2
# Out:
# True

# %%
'g' in ts2
# Out:
# False

# %%
ts2.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
# how to create Series
ts1 = pd.Series([8, 24, 16, 4, 42])
ts2 = pd.Series([8, 24, 16, 4, 42], index=['a','b','c','d','e'])
population = {"turkey": 80_000_000, 'france': 70_000_000, 'italy': 60_000_000 }
ts3 = pd.Series(population) # key -> index, value -> values

# %%
ts3
# Out:
# turkey    80000000
# france    70000000
# italy     60000000
# dtype: int64

# %%
ts3.index
# Out:
# Index(['turkey', 'france', 'italy'], dtype='object')

# %%
ts3.values
# Out:
# array([80000000, 70000000, 60000000])

# %%
ts3['turkey']
# Out:
# 80000000

# %%
"turkey" in ts3
# Out:
# True

# %%
"japan" in ts3
# Out:
# False

# %%
# 2. DataFrame : tabular like tables in relational database

# %%
world = {
    'country': ['turkey', 'france', 'italy' ],
    'population': [80_000_000, 70_000_000, 60_000_000],
    'surface_area' : [120_000_000, 130_000_000, 90_000_000],
    'capital' : ['ankara', 'paris', 'rome'] 
}
df1 = pd.DataFrame(world)

# %%
df1
# Out:
#   country  population  surface_area capital
# 0  turkey    80000000     120000000  ankara
# 1  france    70000000     130000000   paris
# 2   italy    60000000      90000000    rome

# %%
df1.head(2)
# Out:
#   country  population  surface_area capital
# 0  turkey    80000000     120000000  ankara
# 1  france    70000000     130000000   paris

# %%
df1.tail(1)
# Out:
#   country  population  surface_area capital
# 2   italy    60000000      90000000    rome

# %%
df2 = pd.DataFrame(world, columns=["country","population"])

# %%
df2
# Out:
#   country  population
# 0  turkey    80000000
# 1  france    70000000
# 2   italy    60000000

# %%
df2.columns
# Out:
# Index(['country', 'population'], dtype='object')

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df1['population']
# Out:
# 0    80000000
# 1    70000000
# 2    60000000
# Name: population, dtype: int64

# %%
df1.population
# Out:
# 0    80000000
# 1    70000000
# 2    60000000
# Name: population, dtype: int64

# %%
df1
# Out:
#   country  population  surface_area capital
# 0  turkey    80000000     120000000  ankara
# 1  france    70000000     130000000   paris
# 2   italy    60000000      90000000    rome

# %%
continents = pd.Series(['Asia','Europe','Europe'], index=[0,1,2])

# %%
df1['continent'] = continents

# %%
df1
# Out:
#   country  population  surface_area capital continent
# 0  turkey    80000000     120000000  ankara      Asia
# 1  france    70000000     130000000   paris    Europe
# 2   italy    60000000      90000000    rome    Europe

# %%
# How to remove a column from DataFrame
# del df1['continent']

# %%
df1['rich'] = df1.country != 'turkey'

# %%
df1
# Out:
#   country  population  surface_area capital continent   rich
# 0  turkey    80000000     120000000  ankara      Asia  False
# 1  france    70000000     130000000   paris    Europe   True
# 2   italy    60000000      90000000    rome    Europe   True

# %%
orders = {
    'symbol': ['orcl', 'msft', 'ibm' , 'goggl'],
    'price': [123.34, 98.23, 64.93, 143.56],
    'quantity' : [120, 130, 90, 200] 
}
df3 = pd.DataFrame(orders)

# %%
df3
# Out:
#   symbol   price  quantity
# 0   orcl  123.34       120
# 1   msft   98.23       130
# 2    ibm   64.93        90
# 3  goggl  143.56       200

# %%
df3['volume'] = df3.price * df3.quantity # vectorized + element-wise

# %%
df3
# Out:
#   symbol   price  quantity   volume
# 0   orcl  123.34       120  14800.8
# 1   msft   98.23       130  12769.9
# 2    ibm   64.93        90   5843.7
# 3  goggl  143.56       200  28712.0

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   symbol    4 non-null      object
#  1   price     4 non-null      float64
#  2   quantity  4 non-null      int64
#  3   volume    4 non-null      float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 256.0+ bytes

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   country       3 non-null      object
#  1   population    3 non-null      int64
#  2   surface_area  3 non-null      int64
#  3   capital       3 non-null      object
#  4   continent     3 non-null      object
#  5   rich          3 non-null      bool
# dtypes: bool(1), int64(2), object(3)
# memory usage: 251.0+ bytes

# %%
df1.describe()
# Out:
#        population  surface_area
# count         3.0  3.000000e+00
# mean   70000000.0  1.133333e+08
# std    10000000.0  2.081666e+07
# min    60000000.0  9.000000e+07
# 25%    65000000.0  1.050000e+08
# 50%    70000000.0  1.200000e+08
# 75%    75000000.0  1.250000e+08
# max    80000000.0  1.300000e+08

# %%
df3.describe()
# Out:
#             price    quantity        volume
# count    4.000000    4.000000      4.000000
# mean   107.515000  135.000000  15531.600000
# std     33.908534   46.547467   9587.133845
# min     64.930000   90.000000   5843.700000
# 25%     89.905000  112.500000  11038.350000
# 50%    110.785000  125.000000  13785.350000
# 75%    128.395000  147.500000  18278.600000
# max    143.560000  200.000000  28712.000000

# %%
df3.cov()
# Out:
#                 price       quantity        volume
# price       1149.7887    1356.100000  3.005747e+05
# quantity    1356.1000    2166.666667  4.391507e+05
# volume    300574.7380  439150.666667  9.191314e+07

# %%
df3
# Out:
#   symbol   price  quantity   volume
# 0   orcl  123.34       120  14800.8
# 1   msft   98.23       130  12769.9
# 2    ibm   64.93        90   5843.7
# 3  goggl  143.56       200  28712.0

# %%
df4 = df3.T

# %%
df4
# Out:
#                 0        1       2       3
# symbol       orcl     msft     ibm   goggl
# price      123.34    98.23   64.93  143.56
# quantity      120      130      90     200
# volume    14800.8  12769.9  5843.7   28712

# %%
df3
# Out:
#   symbol   price  quantity   volume
# 0   orcl  123.34       120  14800.8
# 1   msft   98.23       130  12769.9
# 2    ibm   64.93        90   5843.7
# 3  goggl  143.56       200  28712.0

# %%
type(df3['price'].values)
# Out:
# numpy.ndarray

# %%
'symbol' in df3.columns
# Out:
# True

# %%
3 in df3.index
# Out:
# True

# %%
df3.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
10 in df3.index
# Out:
# False

# %%
ts4 = pd.Series(['blue', 'purple', 'yellow', 'green'], index=[0,2,4,6])

# %%
ts4
# Out:
# 0      blue
# 2    purple
# 4    yellow
# 6     green
# dtype: object

# %%
ts4.reindex([0,1,2,3,4,5,6], method='ffill') # forward fill
# Out:
# 0      blue
# 1      blue
# 2    purple
# 3    purple
# 4    yellow
# 5    yellow
# 6     green
# dtype: object

# %%
df5 = pd.DataFrame(np.arange(9).reshape((3,3)), index=['a', 'c','d'],
                   columns=['turkey', 'france', 'italy'])

# %%
df5
# Out:
#    turkey  france  italy
# a       0       1      2
# c       3       4      5
# d       6       7      8

# %%
df6 = df5.reindex(['a', 'b','c','d'])

# %%
df6
# Out:
#    turkey  france  italy
# a     0.0     1.0    2.0
# b     NaN     NaN    NaN
# c     3.0     4.0    5.0
# d     6.0     7.0    8.0

# %%
# float('nan'), np.nan
# Out:
# nan

# %%
df7 = df6.reindex(columns=['turkey', 'italy', 'japan'])

# %%
df7
# Out:
#    turkey  italy  japan
# a     0.0    2.0    NaN
# b     NaN    NaN    NaN
# c     3.0    5.0    NaN
# d     6.0    8.0    NaN

# %%
df6.drop('france',axis=1,inplace=True)

# %%
df6
# Out:
#    turkey  italy
# a     0.0    2.0
# b     NaN    NaN
# c     3.0    5.0
# d     6.0    8.0
