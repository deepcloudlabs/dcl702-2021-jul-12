# %%
# Basic Data Structures in Python
# 1. Tuple     : (4,8,15,16,23,42,8,16)     immutable, allows duplicates, linear search
# 2. List      : [4,8,15,16,23,42,8,16]     mutable, allows duplicates, linear search
# 3. Set       : {4,8,15,16,23,42}          mutable, unique, tree, hashing
# 4. Dictionary: { "ankara": 312, "izmir": 232, "antalya": 242} mutable,key (str)-> value (int), unique (key), hashing

# %%
numbers = (4,8,15,16,23,42,8,16) # tuple

# %%
numbers[0]
# Out:
# 4

# %%
numbers[-1]
# Out:
# 16

# %%
numbers
# Out:
# (4, 8, 15, 16, 23, 42, 8, 16)

# %%
numbers[::-1]
# Out:
# (16, 8, 42, 23, 16, 15, 8, 4)

# %%
numbers[0:7:3]
# Out:
# (4, 16, 8)

# %%
numbers[0:3]
# Out:
# (4, 8, 15)

# %%
len(numbers)
# Out:
# 8

# %%
numbers.count(8) # linear search
# Out:
# 2

# %%
numbers.count(108) > 0
# Out:
# False

# %%
numbers.index(8)
# Out:
# 1

# %%
numbers.index(8,2,9)
# Out:
# 6

# %%
numbers.count(108)
# Out:
# 0

# %%
try:
  numbers.index(108)
except ValueError as e:
  print("Cannot find 108")
# Out:
# Cannot find 108

# %%
names = ["jack", "kate", "james"]

# %%
len(names)
# Out:
# 3

# %%
names[0]
# Out:
# 'jack'

# %%
names[0] = "Jack"

# %%
names
# Out:
# ['Jack', 'kate', 'james']

# %%
names.append('ben')

# %%
names.append("hugo")

# %%
names
# Out:
# ['Jack', 'kate', 'james', 'ben', 'hugo']

# %%
del names[3]

# %%
names
# Out:
# ['Jack', 'kate', 'james', 'hugo']

# %%
names.insert(0, 'sun')

# %%
names.insert(0, 'jin')

# %%
names
# Out:
# ['jin', 'sun', 'Jack', 'kate', 'james', 'hugo']

# %%
full_name = 'kate austen'

# %%
full_name = "kate austen"

# %%
full_name = "kate's car"

# %%
full_name = "\"kate\""

# %%
print(full_name)
# Out:
# "kate"

# %%
full_text="""This is the first line.
This is the second line.
This is the third line.
This is the last line.
"""

# %%
full_text= "This is the first line.\nThis is the second line.\nThis is the third line.\nThis is the last line.\n"

# %%
xml_data = """<employee>
  <first_name>jack</first_name>
  <last_name>bauer</last_name>
</employee>
"""

# %%
for name in names: print(name)
# Out:
# jin
# sun
# Jack
# kate
# james
# hugo

# %%
print(str(names))
# Out:
# ['jin', 'sun', 'Jack', 'kate', 'james', 'hugo']

# %%
numbers
# Out:
# (4, 8, 15, 16, 23, 42, 8, 16)

# %%
sorted(numbers, reverse=True)
# Out:
# [42, 23, 16, 16, 15, 8, 8, 4]

# %%
names
# Out:
# ['jin', 'sun', 'Jack', 'kate', 'james', 'hugo']

# %%
names.sort()

# %%
names = ['JACK', 'huGO', 'JaMeS', 'JiN', 'kaTE', 'sUN']

# %%
names.sort(key= str.lower)

# %%
names
# Out:
# ['hugo', 'Jack', 'james', 'jin', 'kate', 'sun']

# %%
def to_lower(s):
  return s.lower()

# %%
def uzunluk(s):
  return len(s)

# %%
to_lower("JACK")
# Out:
# 'jack'

# %%
names.sort(key= uzunluk) # ['jack', 'hugo', 'james', 'jin', 'kate', 'sUN'  ]

# %%
names
# Out:
# ['JiN', 'sUN', 'huGO', 'JACK', 'kaTE', 'JaMeS']

# %%
names.sort(key=len) # inplace

# %%
names
# Out:
# ['JiN', 'sUN', 'huGO', 'JACK', 'kaTE', 'JaMeS']

# %%
numbers # tuple
# Out:
# (4, 8, 15, 16, 23, 42, 8, 16)

# %%
sorted_numbers = sorted(numbers) # returns list

# %%
print(numbers)
print(sorted_numbers)
# Out:
# (4, 8, 15, 16, 23, 42, 8, 16)
# [4, 8, 8, 15, 16, 16, 23, 42]

# %%
# names2 = names[:]
names2 = names.copy() # clone
names2.sort()

# %%
names2
# Out:
# ['JiN', 'sUN', 'huGO', 'JACK', 'kaTE']

# %%
names
# Out:
# ['JiN', 'sUN', 'huGO', 'JACK', 'kaTE']

# %%
del names2[-1]

# %%
names2
# Out:
# ['JiN', 'sUN', 'huGO', 'JACK']

# %%
names
# Out:
# ['JiN', 'sUN', 'huGO', 'JACK', 'kaTE']

# %%
names= ["jack" ,"ben", "kate", "hugo","james"]

# %%
names
# Out:
# ['jack', 'ben', 'kate', 'hugo', 'james']

# %%
sorted_names = sorted(names) # cloning + sorted

# %%
sorted_names
# Out:
# ['ben', 'hugo', 'jack', 'james', 'kate']

# %%
names
# Out:
# ['jack', 'ben', 'kate', 'hugo', 'james']

# %%
numbers = set([4,8,15,16,23,42,4,8,15,16,23,42,4,8,15,16,23,42])

# %%
numbers
# Out:
# {4, 8, 15, 16, 23, 42}

# %%
numbers.add(42)

# %%
numbers
# Out:
# {4, 8, 15, 16, 23, 42}

# %%
numbers.add(42)

# %%
numbers
# Out:
# {4, 8, 15, 16, 23, 42}

# %%
108 in numbers #set: O(1)
# Out:
# False

# %%
sayilar = [4,8,15,16,23,42]

# %%
108 in sayilar
# Out:
# False
